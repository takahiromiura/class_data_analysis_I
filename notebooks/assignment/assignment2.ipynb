# %% [markdown]
# # 課題に関する注意
#
# - 元のコードセルは削除しないでください
# - 提出用のファイルは、`ファイル -> ダウンロード -> .ipynb をダウンロード` でダウンロードします (.py ファイルではありません）。
# - ファイル提出前に `ランタイム -> セッションを再起動して全て実行する` を行ってください。
# - 最後まで実行できないファイルは評価対象外です

# %% [markdown]
# # 課題 2
#
# 以下は Stack Overflow の解答のデータの一部です。
#
# - [データ URL](https://api.stackexchange.com/docs/answers#fromdate=2024-07-09&todate=2024-07-10&order=desc&sort=activity&filter=default&site=stackoverflow&run=true)
#
# このデータは各解答の情報のリストが `items` キーの値として格納されています。
#
# また、解答には解答者 (owner) の情報が紐づいています。
#
# このデータを用いて、以下の分析を行ってください。

# %%
data = {
  "items": [
    {
      "owner": {
        "account_id": 33945856,
        "reputation": 1,
        "user_id": 26303326,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720760441,
      "last_edit_date": 1720760441,
      "creation_date": 1720525835,
      "answer_id": 78725410,
      "question_id": 40073040,
    },
    {
      "owner": {
        "account_id": 19270674,
        "reputation": 548,
        "user_id": 14084653,
        "user_type": "registered",
      },
      "is_accepted": True,
      "score": 0,
      "last_activity_date": 1720733282,
      "last_edit_date": 1720733282,
      "creation_date": 1720496424,
      "answer_id": 78723592,
      "question_id": 78720683,
    },
    {
      "owner": {
        "account_id": 9852716,
        "reputation": 1,
        "user_id": 7298271,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720723738,
      "last_edit_date": 1720723738,
      "creation_date": 1720547013,
      "answer_id": 78727052,
      "question_id": 54483770,
    },
    {
      "owner": {
        "account_id": 7465896,
        "reputation": 1,
        "user_id": 5675484,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720723449,
      "last_edit_date": 1720723449,
      "creation_date": 1720509047,
      "answer_id": 78724160,
      "question_id": 78599678,
    },
    {
      "owner": {
        "account_id": 3768825,
        "reputation": 3844,
        "user_id": 5958842,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720722156,
      "last_edit_date": 1720722156,
      "creation_date": 1720561785,
      "answer_id": 78727863,
      "question_id": 78727459,
    },
    {
      "owner": {
        "account_id": 1432472,
        "reputation": 2218,
        "user_id": 1354580,
        "user_type": "registered",
        "accept_rate": 78,
      },
      "is_accepted": True,
      "score": 1,
      "last_activity_date": 1720718790,
      "last_edit_date": 1720718790,
      "creation_date": 1720523109,
      "answer_id": 78725219,
      "question_id": 78723078,
    },
    {
      "owner": {
        "account_id": 12803814,
        "reputation": 20475,
        "user_id": 9264230,
        "user_type": "registered",
      },
      "is_accepted": True,
      "score": 1,
      "last_activity_date": 1720718259,
      "last_edit_date": 1720718259,
      "creation_date": 1720552137,
      "answer_id": 78727376,
      "question_id": 78726721,
    },
    {
      "owner": {
        "account_id": 6897470,
        "reputation": 20052,
        "user_id": 5298879,
        "user_type": "registered",
      },
      "is_accepted": True,
      "score": 4,
      "last_activity_date": 1720718138,
      "last_edit_date": 1720718138,
      "creation_date": 1720526793,
      "answer_id": 78725490,
      "question_id": 78724069,
    },
    {
      "owner": {
        "account_id": 5188369,
        "reputation": 11,
        "user_id": 23620715,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 1,
      "last_activity_date": 1720714206,
      "last_edit_date": 1720714206,
      "creation_date": 1720506252,
      "answer_id": 78723964,
      "question_id": 78716750,
    },
    {
      "owner": {
        "account_id": 33936335,
        "reputation": 1,
        "user_id": 26295228,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1

        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720679751,
      "last_edit_date": 1720679751,
      "creation_date": 1720534545,
      "answer_id": 78726145,
      "question_id": 78720541,
    },
    {
      "owner": {
        "account_id": 29308862,
        "reputation": 11,
        "user_id": 22455213,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 1,
      "last_activity_date": 1720679724,
      "last_edit_date": 1720679724,
      "creation_date": 1720511300,
      "answer_id": 78724323,
      "question_id": 76546457,
    },
    {
      "owner": {
        "account_id": 30437131,
        "reputation": 1,
        "user_id": 23324890,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720672280,
      "last_edit_date": 1720672280,
      "creation_date": 1720533415,
      "answer_id": 78726039,
      "question_id": 65715905,
    },
    {
      "owner": {
        "account_id": 22387743,
        "reputation": 3866,
        "user_id": 16600319,
        "user_type": "registered",
      },
      "is_accepted": True,
      "score": 0,
      "last_activity_date": 1720665448,
      "last_edit_date": 1720665448,
      "creation_date": 1720503688,
      "answer_id": 78723832,
      "question_id": 78722889,
    },
    {
      "owner": {
        "account_id": 14517085,
        "reputation": 27,
        "user_id": 11718631,
        "user_type": "registered",
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720660654,
      "last_edit_date": 1720660654,
      "creation_date": 1720555268,
      "answer_id": 78727560,
      "question_id": 78724459,
    },
    {
      "owner": {
        "account_id": 8512965,
        "reputation": 17262,
        "user_id": 6382434,
        "user_type": "registered",
        "accept_rate": 75,
      },
      "is_accepted": False,
      "score": 0,
      "last_activity_date": 1720656612,
      "last_edit_date": 1720656612,
      "creation_date": 1720540651,
      "answer_id": 78726609,
      "question_id": 11952706,
    },
    {
      "owner": {
        "account_id": 94036,
        "reputation": 109898,
        "user_id": 256970,
        "user_type": "registered",
        "accept_rate": 86,
      },
      "is_accepted": False,
      "score": 3,
      "last_activity_date": 1720645410,
      "last_edit_date": 1720645410,
      "creation_date": 1720558634,
      "answer_id": 78727706,
      "question_id": 78723505,
    }
  ],
  "has_more": True,
  "quota_max": 10000,
  "quota_remaining": 9986
}

# %% [markdown]
# ## 問 1
#
# このデータには、いくつの解答データが含まれていますか。
#
# 以下のコードセルで、`len` 関数を用いて計算してください。

# %% [markdown]
# ## 問 2
#
# 各解答には、他者からの評価値が `score` として記載されています。
#
# ループ処理を用いて、解答の評価値の平均値を以下のコードセルで計算してください。

# %% [markdown]
# ## 問 3
#
# 登録ユーザーの Stack Overflow に対する貢献度は評価ポイント `reputation` として表されます。
#
# ループ処理を用いて、評価ポイントの平均値を以下のコードセルで計算してください。

# %% [markdown]
# ## 問 4
#
# 評価ポイントが 100 以上なら 1、それ未満なら 0 をとる関数を以下のコードセル内に作成してください。

# %% [markdown]
# ## 問 5
#
# 問 4 で作成した関数が正しく動作することを、以下の数値を入れて確認してくだい。
#
# - 100
# - 2000
# - 1
#
# 出力結果は以下のコードセル内にまとめてください。
#
# ヒント: `print` 関数を用いれば、複数の結果を出力できます。

# %% [markdown]
# ## 問 6
#
# 問 4 で作成した関数を用いて、評価ポイントが 100 以上の人が解答者である割合は全体の何% ですか。
#
# ループ処理を用いて、以下のコードセル内に計算結果を出力してください。
